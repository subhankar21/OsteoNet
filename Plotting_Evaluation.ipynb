# %%
import numpy as np
import matplotlib.pyplot as plt
import os
train_loss = np.loadtxt('../PhD Work/Advanced AI/Results/train_loss.txt')
test_loss = np.loadtxt('../PhD Work/Advanced AI/Results/val_loss.txt')
train_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/train_accuracy.txt')
test_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/val_accuracy.txt')
train_top_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/train_top-1-accuracy.txt')
test_top_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/val_top_1_accuracy.txt')
# train_loss = np.loadtxt('../PhD Work/Advanced AI/Results/train_loss.txt')

# val_s = []
# import random
# for i in range(len(resnet_50)):
#     random_n = random.random()
#     g = resnet_50[i]+0.001*random_n
#     val_s.append(g)

# train_s =[]   
# for i in range(len(resnet_50)):
#     random_n = random.random()
#     g = resnet_50[i]+0.009*random_n
#     train_s.append(g)

# import numpy as np
# import matplotlib.pyplot as plt
# # cap_acc = np.loadtxt('capsnet_acc_final.txt')
# # val_cap_acc = s

epochs = range(1, len(train_accuracy) + 1)
plt.figure(figsize=(12,8))
plt.plot(epochs, train_accuracy, 'bo-',markersize=2, label='Training Accuracy')
plt.plot(epochs, test_accuracy, 'r*-', markersize=2, label='Validation Accuracy')

plt.grid(True)
plt.title('Training & Validation Accuracy over the Epochs',fontsize=25)
plt.legend(loc='best',fontsize=25)
plt.ylabel('Accuracy',fontsize=25)
plt.xlabel('Epoch',fontsize=25)
plt.tick_params(labelsize=25)
plt.tick_params(labelsize=25)
plt.tick_params(labelsize=25)
plt.savefig('../PhD Work/Advanced AI/Results/Plots/Training & Validation Accuracy.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
train_loss = np.loadtxt('../PhD Work/Advanced AI/Results/train_loss.txt')
test_loss = np.loadtxt('../PhD Work/Advanced AI/Results/val_loss.txt')
train_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/train_accuracy.txt')
test_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/val_accuracy.txt')
train_top_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/train_top-1-accuracy.txt')
test_top_accuracy = np.loadtxt('../PhD Work/Advanced AI/Results/val_top_1_accuracy.txt')
# train_loss = np.loadtxt('../PhD Work/Advanced AI/Results/train_loss.txt')

# val_s = []
# import random
# for i in range(len(resnet_50)):
#     random_n = random.random()
#     g = resnet_50[i]+0.001*random_n
#     val_s.append(g)

# train_s =[]   
# for i in range(len(resnet_50)):
#     random_n = random.random()
#     g = resnet_50[i]+0.009*random_n
#     train_s.append(g)

# import numpy as np
# import matplotlib.pyplot as plt
# # cap_acc = np.loadtxt('capsnet_acc_final.txt')
# # val_cap_acc = s

epochs = range(1, len(train_accuracy) + 1)
plt.figure(figsize=(12,8))
plt.plot(epochs, train_loss, 'md--',markersize=2, label='Training Loss')
plt.plot(epochs, test_loss, 'g*-', markersize=2, label='Validation Loss')

plt.grid(True)
plt.title('Training & Validation Loss over the Epochs',fontsize=25)
plt.legend(loc='best',fontsize=25)
plt.ylabel('Loss',fontsize=25)
plt.xlabel('Epoch',fontsize=25)
plt.tick_params(labelsize=25)
plt.tick_params(labelsize=25)
plt.tick_params(labelsize=25)
plt.savefig('../PhD Work/Advanced AI/Results/Plots/Training & Validation Loss.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
path = '../PhD Work/Advanced AI/Results/'
Y_Test_rounded = np.loadtxt(path+'/y_test_rounded.txt')
rounded_prediction = np.loadtxt(path+'/Rounded_prediction.txt')

from sklearn.metrics import cohen_kappa_score, f1_score, recall_score, precision_score, classification_report, accuracy_score
# print(classification_report(y_true, y_pred, target_names=target_names))
# print(classification_report(y_true=Y_Test_rounded, y_pred=rounded_prediction))
# print(cohen_kappa_score(Y_Test_rounded, rounded_prediction))
print('accuracy_score', accuracy_score(Y_Test_rounded, rounded_prediction))
print('f1score macro', f1_score(Y_Test_rounded, rounded_prediction, average='macro'))
print('f1score micro',f1_score(Y_Test_rounded, rounded_prediction, average='micro'))
print('f1score weighted',f1_score(Y_Test_rounded, rounded_prediction, average='weighted'))
print('recall macro', recall_score(Y_Test_rounded, rounded_prediction, average='macro'))
print('recall micro',recall_score(Y_Test_rounded, rounded_prediction, average='micro'))
print('recall weighted', recall_score(Y_Test_rounded, rounded_prediction, average='weighted'))
print('precision_score macro', precision_score(Y_Test_rounded, rounded_prediction, average='macro'))
print('precision_score micro',precision_score(Y_Test_rounded, rounded_prediction, average='micro'))
print('precision_score weighted', precision_score(Y_Test_rounded, rounded_prediction, average='weighted'))
# Out:
# accuracy_score 0.954337899543379
# f1score macro 0.9453126522198986
# f1score micro 0.954337899543379
# f1score weighted 0.9544779535521917
# recall macro 0.9502842871565971
# recall micro 0.954337899543379
# recall weighted 0.954337899543379
# precision_score macro 0.9414141414141414
# precision_score micro 0.954337899543379
# precision_score weighted 0.955458696554587
